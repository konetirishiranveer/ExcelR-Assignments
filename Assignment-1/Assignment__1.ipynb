# %% [markdown]
# BASIC PYTHON

# %% [markdown]
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
num = int(input("enter the prime number:"))
if num <=1:
   print("not a prime number")
else:
   print("prime number")
for i in range(2,num):
  if num % i==0:
    print("not a prime number")
    break
else:
    print("prime number")
# Out:
# enter the prime number:3
# prime number
# prime number

# %% [markdown]
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
a = random.randint(0,10)
b = random.randint(0,10)
print(a,b)
answer = int(input('enter the answer : '))
if answer == (a*b):
  print('the answer you have entered is correct and keep on going')
else:
  print('you have enterd the wrong answer try your luck next time')
# Out:
# 6 4
# enter the answer : 3
# you have enterd the wrong answer try your luck next time

# %% [markdown]
# 3.Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
for num in range(101,201,2):
  print("the number is :",num,"\n the square of the number:",num**2 )
# Out:
# the number is : 101
#  the square of the number: 10201
# the number is : 103
#  the square of the number: 10609
# the number is : 105
#  the square of the number: 11025
# the number is : 107
#  the square of the number: 11449
# the number is : 109
#  the square of the number: 11881
# the number is : 111
#  the square of the number: 12321
# the number is : 113
#  the square of the number: 12769
# the number is : 115
#  the square of the number: 13225
# the number is : 117
#  the square of the number: 13689
# the number is : 119
#  the square of the number: 14161
# the number is : 121
#  the square of the number: 14641
# the number is : 123
#  the square of the number: 15129
# the number is : 125
#  the square of the number: 15625
# the number is : 127
#  the square of the number: 16129
# the number is : 129
#  the square of the number: 16641
# the number is : 131
#  the square of the number: 17161
# the number is : 133
#  the square of the number: 17689
# the number is : 135
#  the square of the number: 18225
# the number is : 137
#  the square of the number: 18769
# the number is : 139
#  the square of the number: 19321
# the number is : 141
#  the square of the number: 19881
# the number is : 143
#  the square of the number: 20449
# the number is : 145
#  the square of the number: 21025
# the number is : 147
#  the square of the number: 21609
# the number is : 149
#  the square of the number: 22201
# the number is : 151
#  the square of the number: 22801
# the number is : 153
#  the square of the number: 23409
# the number is : 155
#  the square of the number: 24025
# the number is : 157
#  the square of the number: 24649
# the number is : 159
#  the square of the number: 25281
# the number is : 161
#  the square of the number: 25921
# the number is : 163
#  the square of the number: 26569
# the number is : 165
#  the square of the number: 27225
# the number is : 167
#  the square of the number: 27889
# the number is : 169
#  the square of the number: 28561
# the number is : 171
#  the square of the number: 29241
# the number is : 173
#  the square of the number: 29929
# the number is : 175
#  the square of the number: 30625
# the number is : 177
#  the square of the number: 31329
# the number is : 179
#  the square of the number: 32041
# the number is : 181
#  the square of the number: 32761
# the number is : 183
#  the square of the number: 33489
# the number is : 185
#  the square of the number: 34225
# the number is : 187
#  the square of the number: 34969
# the number is : 189
#  the square of the number: 35721
# the number is : 191
#  the square of the number: 36481
# the number is : 193
#  the square of the number: 37249
# the number is : 195
#  the square of the number: 38025
# the number is : 197
#  the square of the number: 38809
# the number is : 199
#  the square of the number: 39601

# %% [markdown]
# ✅ Problem Statement (Question): Hospital Billing System
# A hospital charges its patients based on the following:
# Room charges per day: ₹2,000
# Doctor consultation fee (flat): ₹1,500
# Lab test charges: Based on the number of tests taken. Each test costs ₹300
# Medicine charges: Total cost of medicines provided
# Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# Stayed for 4 days
# Had 3 lab tests
# Had medicine charges of ₹2,400

# %%
charges = 2000*4
print(charges)
labs =300*3
print(labs)
meds =2400
print(meds)
doctor =1500
print(doctor)
finalbill = (charges+labs+meds+doctor)
discount = 10000/12800
print(discount)
discount = finalbill *0.10
finalamount =finalbill -discount
print(finalamount)
# Out:
# 8000
# 900
# 2400
# 1500
# 0.78125
# 11520.0
